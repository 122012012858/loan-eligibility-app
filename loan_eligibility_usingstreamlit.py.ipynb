# %%
pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.3.4)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\appdata\roaming\python\python39\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Sample dataset
data = {
    'Age': [25, 35, 45, 20, 30, 50, 40],
    'Income': [50000, 60000, 80000, 20000, 40000, 100000, 70000],
    'LoanAmount': [10000, 20000, 15000, 5000, 12000, 25000, 18000],
    'CreditScore': [700, 650, 800, 600, 620, 750, 680],
    'Eligible': [1, 1, 1, 0, 0, 1, 1]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Features and target
X = df[['Age', 'Income', 'LoanAmount', 'CreditScore']]
y = df['Eligible']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Predict new applicant
def predict_eligibility(age, income, loan_amount, credit_score):
    input_data = pd.DataFrame([[age, income, loan_amount, credit_score]],
                              columns=['Age', 'Income', 'LoanAmount', 'CreditScore'])
    prediction = model.predict(input_data)
    return "Eligible" if prediction[0] == 1 else "Not Eligible"

# Example usage
#print(predict_eligibility(28, 55000, 10000, 690))
# Out:
# Accuracy: 0.6666666666666666

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\programdata\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: semver in c:\programdata\anaconda3\lib\site-packages (from streamlit) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (4.8.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from streamlit) (14.2.0)
# Requirement already satisfied: cachetools>=4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: validators>=0.2 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (0.35.0)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (8.0.3)
# Requirement already satisfied: watchdog in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: numpy in c:\users\admin\appdata\roaming\python\python39\site-packages (from streamlit) (1.22.4)
# Requirement already satisfied: pyarrow>=4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: altair>=3.2.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: requests>=2.4 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: gitpython!=3.1.19 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: packaging>=14.1 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (21.0)
# Requirement already satisfied: pympler>=0.9 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (1.1)
# Requirement already satisfied: toml in c:\programdata\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: tornado>=5.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: tzlocal>=1.1 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: blinker>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\programdata\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: pywin32>=226 in c:\programdata\anaconda3\lib\site-packages (from pympler>=0.9->streamlit) (228)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from rich>=10.11.0->streamlit) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from rich>=10.11.0->streamlit) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2025.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in c:\programdata\anaconda3\lib\site-packages (6.0.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\lib\site-packages (from altair) (3.2.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from altair) (21.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from altair) (4.15.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: narwhals>=1.27.1 in c:\programdata\anaconda3\lib\site-packages (from altair) (2.11.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (21.2.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (1.16.0)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yparsing (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->altair) (3.0.4)

# %%
import altair as alt
print(alt.__version__)
# Out:
# 6.0.0

# %%
import streamlit as st
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

data = {
    'Age': [25, 35, 45, 20, 30, 50, 40],
    'Income': [50000, 60000, 80000, 20000, 40000, 100000, 70000],
    'LoanAmount': [10000, 20000, 15000, 5000, 12000, 25000, 18000],
    'CreditScore': [700, 650, 800, 600, 620, 750, 680],
    'Eligible': [1, 1, 1, 0, 0, 1, 1]
}

df = pd.DataFrame(data)
X = df[['Age', 'Income', 'LoanAmount', 'CreditScore']]
y = df['Eligible']

model = DecisionTreeClassifier()
model.fit(X, y)

st.title("🏦 Bank Loan Eligibility Predictor")

st.sidebar.header("Applicant Info")
age = st.sidebar.slider("Age", 18, 70, 30)
income = st.sidebar.number_input("Annual Income", 10000, 200000, 50000)
loan_amount = st.sidebar.number_input("Loan Amount", 1000, 50000, 10000)
credit_score = st.sidebar.slider("Credit Score", 300, 850, 650)

if st.sidebar.button("Check Eligibility"):
    input_data = pd.DataFrame([[age, income, loan_amount, credit_score]],
                              columns=['Age', 'Income', 'LoanAmount', 'CreditScore'])
    prediction = model.predict(input_data)
    result = "✅ Eligible for Loan" if prediction[0] == 1 else "❌ Not Eligible for Loan"
    st.subheader("Prediction Result")
    st.success(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6072/4245873586.py in <module>
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 from sklearn.tree import DecisionTreeClassifier
#       4
#       5 data = {
#
# C:\ProgramData\Anaconda3\lib\site-packages\streamlit\__init__.py in <module>
#      68 from streamlit import source_util as _source_util
#      69 from streamlit import string_util as _string_util
# ---> 70 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      71 from streamlit.runtime.scriptrunner import (
#      72     add_script_run_ctx as _add_script_run_ctx,
#
# C:\ProgramData\Anaconda3\lib\site-packages\streamlit\delta_generator.py in <module>
#      88 # We select between them with the DataFrameElementSelectorMixin.
#      89 from streamlit.elements.arrow import ArrowMixin
# ---> 90 from streamlit.elements.arrow_altair import ArrowAltairMixin
#      91 from streamlit.elements.arrow_vega_lite import ArrowVegaLiteMixin
#      92 from streamlit.elements.legacy_data_frame import LegacyDataFrameMixin
#
# C:\ProgramData\Anaconda3\lib\site-packages\streamlit\elements\arrow_altair.py in <module>
#      33 import altair as alt
#      34 import pandas as pd
# ---> 35 from altair.vegalite.v4.api import Chart
#      36 from pandas.api.types import infer_dtype
#      37
#
# ModuleNotFoundError: No module named 'altair.vegalite.v4'

# %%
# !streamlit run loan_eligibility_usingstreamlit.py
# Out:
# 2025-11-14 07:48:41.417 INFO    numexpr.utils: Note: NumExpr detected 28 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2025-11-14 07:48:41.417 INFO    numexpr.utils: NumExpr defaulting to 8 threads.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\Scripts\streamlit.exe\__main__.py", line 4, in <module>
#   File "C:\ProgramData\Anaconda3\lib\site-packages\streamlit\__init__.py", line 70, in <module>
#     from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#   File "C:\ProgramData\Anaconda3\lib\site-packages\streamlit\delta_generator.py", line 90, in <module>
#     from streamlit.elements.arrow_altair import ArrowAltairMixin
#   File "C:\ProgramData\Anaconda3\lib\site-packages\streamlit\elements\arrow_altair.py", line 35, in <module>
#     from altair.vegalite.v4.api import Chart
# ModuleNotFoundError: No module named 'altair.vegalite.v4'
